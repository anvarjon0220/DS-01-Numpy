# %%
import numpy as np

# %%
my_list = list(range(100000))
my_array = np.array(range(100000))

# %%
# %time for  _ in range(10) : [x*2 for x in my_list] # normal hisoblash
# Out:
# CPU times: user 79.2 ms, sys: 12.1 ms, total: 91.2 ms
# Wall time: 94.5 ms

# %%
# %time for _ in range(10) : my_array*2 # vektorlashgan hisoblash
# Out:
# CPU times: user 3.2 ms, sys: 14 µs, total: 3.22 ms
# Wall time: 3.31 ms

# %%
94.5/3.31 # tezliklarni taqqoslash
# Out:
# 28.549848942598185
