# %%
import numpy as np

# %%
arr1 = np.array([1, 2, 3], dtype=np.float64)
arr1
# Out:
# array([1., 2., 3.])

# %%
arr2 = np.array([1, 2, 3], dtype=np.int32)
arr2
# Out:
# array([1, 2, 3], dtype=int32)

# %%
arr1.dtype
# Out:
# dtype('float64')

# %%
arr2.dtype
# Out:
# dtype('int32')

# %%
arr = np.array([1, 2, 3, 4]) # int64 ma'lumot turini avtomatik belgilaydi
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
float_arr = arr.astype(np.float64)
float_arr.dtype
# Out:
# dtype('float64')

# %%
float_arr
# Out:
# array([1., 2., 3., 4.])

# %%
data = np.array([3.4, 5.7, 1.8, 4]) # float64 dtype ni avtomatik belgilaydi
data.dtype
# Out:
# dtype('float64')

# %%
int_data = data.astype(np.int64)
int_data
# Out:
# array([3, 5, 1, 4])

# %%
int_data.dtype
# Out:
# dtype('int64')
