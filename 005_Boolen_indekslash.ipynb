# %%
import numpy as np

# %%
# Ismlar
names = np.array(['Hasan', 'Husan', 'Mirzabek', 'Elyor', 'Hasan', 'Javohir', 'Elyor'])
names
# Out:
# array(['Hasan', 'Husan', 'Mirzabek', 'Elyor', 'Hasan', 'Javohir', 'Elyor'],
#       dtype='<U8')

# %%
# data
data = np.random.randn(7, 4)
data
# Out:
# array([[ 0.09604439,  0.83321303,  1.51212277, -2.03087021],
#        [-1.00929903, -0.30654716, -0.80309278,  1.17522858],
#        [-0.93651911, -1.26692987, -1.56062691, -0.6733265 ],
#        [ 0.74873211, -1.31841861, -1.30713015, -0.24218478],
#        [-0.75377677, -0.51559069,  0.54376738, -0.43812007],
#        [ 1.97874152,  0.79322479, -0.59049792,  1.73702037],
#        [-0.83828825,  0.68336996,  2.44175602,  2.04284262]])

# %%
names == 'Hasan'
# Out:
# array([ True, False, False, False,  True, False, False])

# %%
data[names == 'Hasan'] # Hasanga tegishli barcha ma'lumotlarni ajratib olish
# Out:
# array([[ 0.09604439,  0.83321303,  1.51212277, -2.03087021],
#        [-0.75377677, -0.51559069,  0.54376738, -0.43812007]])

# %%
data[names == 'Elyor'] # Elyorga tegishli barcha ma'lumotlarni ajratib olish
# Out:
# array([[ 0.74873211, -1.31841861, -1.30713015, -0.24218478],
#        [-0.83828825,  0.68336996,  2.44175602,  2.04284262]])

# %%
data[names=='Hasan', 2:] # Hasanga tegishli oxirgi ikkita ustundagi ma'lumotlarni ajratib olish
# Out:
# array([[ 1.51212277, -2.03087021],
#        [ 0.54376738, -0.43812007]])

# %%
data[names != 'Hasan'] # (!=)Hasandan tashqari barcha insonlarning ma'lumotlarni ajratib olish
# Out:
# array([[-1.00929903, -0.30654716, -0.80309278,  1.17522858],
#        [-0.93651911, -1.26692987, -1.56062691, -0.6733265 ],
#        [ 0.74873211, -1.31841861, -1.30713015, -0.24218478],
#        [ 1.97874152,  0.79322479, -0.59049792,  1.73702037],
#        [-0.83828825,  0.68336996,  2.44175602,  2.04284262]])

# %%
data[~(names == 'Hasan')] # (~) yuqoridagi cell bilan bir xil natijani berar ekan
# Out:
# array([[-1.00929903, -0.30654716, -0.80309278,  1.17522858],
#        [-0.93651911, -1.26692987, -1.56062691, -0.6733265 ],
#        [ 0.74873211, -1.31841861, -1.30713015, -0.24218478],
#        [ 1.97874152,  0.79322479, -0.59049792,  1.73702037],
#        [-0.83828825,  0.68336996,  2.44175602,  2.04284262]])

# %%
print(names)
print(data)
# Out:
# ['Hasan' 'Husan' 'Mirzabek' 'Elyor' 'Hasan' 'Javohir' 'Elyor']
# [[ 0.09604439  0.83321303  1.51212277 -2.03087021]
#  [-1.00929903 -0.30654716 -0.80309278  1.17522858]
#  [-0.93651911 -1.26692987 -1.56062691 -0.6733265 ]
#  [ 0.74873211 -1.31841861 -1.30713015 -0.24218478]
#  [-0.75377677 -0.51559069  0.54376738 -0.43812007]
#  [ 1.97874152  0.79322479 -0.59049792  1.73702037]
#  [-0.83828825  0.68336996  2.44175602  2.04284262]]

# %%
mask = (names == 'Hasan') | (names == 'Husan') # "|" or (yoki)
mask
# Out:
# array([ True,  True, False, False,  True, False, False])

# %%
data[mask] # Hasan va Husanlarga tegishli ma'lumotlarni ajratib olish
# Out:
# array([[ 0.09604439,  0.83321303,  1.51212277, -2.03087021],
#        [-1.00929903, -0.30654716, -0.80309278,  1.17522858],
#        [-0.75377677, -0.51559069,  0.54376738, -0.43812007]])

# %%
data
# Out:
# array([[ 0.09604439,  0.83321303,  1.51212277, -2.03087021],
#        [-1.00929903, -0.30654716, -0.80309278,  1.17522858],
#        [-0.93651911, -1.26692987, -1.56062691, -0.6733265 ],
#        [ 0.74873211, -1.31841861, -1.30713015, -0.24218478],
#        [-0.75377677, -0.51559069,  0.54376738, -0.43812007],
#        [ 1.97874152,  0.79322479, -0.59049792,  1.73702037],
#        [-0.83828825,  0.68336996,  2.44175602,  2.04284262]])

# %%
data[mask]
# Out:
# array([[ 0.09604439,  0.83321303,  1.51212277, -2.03087021],
#        [-1.00929903, -0.30654716, -0.80309278,  1.17522858],
#        [-0.75377677, -0.51559069,  0.54376738, -0.43812007]])

# %%
data
# Out:
# array([[ 0.09604439,  0.83321303,  1.51212277, -2.03087021],
#        [-1.00929903, -0.30654716, -0.80309278,  1.17522858],
#        [-0.93651911, -1.26692987, -1.56062691, -0.6733265 ],
#        [ 0.74873211, -1.31841861, -1.30713015, -0.24218478],
#        [-0.75377677, -0.51559069,  0.54376738, -0.43812007],
#        [ 1.97874152,  0.79322479, -0.59049792,  1.73702037],
#        [-0.83828825,  0.68336996,  2.44175602,  2.04284262]])

# %%
data[data<0] = 0 # manfiy qiymatlarni 0 ga tenglash

# %%
data
# Out:
# array([[0.09604439, 0.83321303, 1.51212277, 0.        ],
#        [0.        , 0.        , 0.        , 1.17522858],
#        [0.        , 0.        , 0.        , 0.        ],
#        [0.74873211, 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.54376738, 0.        ],
#        [1.97874152, 0.79322479, 0.        , 1.73702037],
#        [0.        , 0.68336996, 2.44175602, 2.04284262]])
