# %% [markdown]
# # transpose - massiv holatini o'zgartirish

# %%
import numpy as np

# %% [markdown]
# **reshape** metodi

# %%
A = np.arange(6).reshape(3,2)
A
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
A.T
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
A.swapaxes(1, 0)
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
np.dot(A, A.T) # A*A^T, ya'ni, massivlarni ko'paytiryapmiz
# Out:
# array([[ 1,  3,  5],
#        [ 3, 13, 23],
#        [ 5, 23, 41]])
